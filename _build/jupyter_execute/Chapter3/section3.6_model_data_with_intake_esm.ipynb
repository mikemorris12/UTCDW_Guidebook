# %% [markdown]
# # Climate Model Data with Intake-ESM
#
# ```{note}
# The code for downloading climate model data in this section was adapted from [this Pangeo tutorial](https://pangeo-data.github.io/pangeo-cmip6-cloud/accessing_data.html#loading-an-esm-collection) and the [Project Pythia CMIP6 Cookbook](https://projectpythia.org/cmip6-cookbook/notebooks/foundations/intake-esm.html) Thanks to Brian Rose and Pascal Bourgault for suggesting the addition of this section.
# ```
#
# In addition to the ESGF archive and direct access to the Google Cloud CMIP data archive with `xr.open_zarr`, the Python package [`intake-esm`](https://intake-esm.readthedocs.io/en/stable/) can be useful for accessing climate model output. `intake-esm` works by accessing what's called an [ESM Collection Specification](https://github.com/NCAR/esm-collection-spec/) (also see [this page](https://intake-esm.readthedocs.io/en/stable/reference/esm-catalog-spec.html)), which describes a database of climate model data. One such databases we could access, which is maintained for the [Pangeo project](https://pangeo.io/), is hosted on Google Cloud Services. We'll work through how to access and search the data catalog and load the data to your local machine.
#
# As usual, we'll import the required packages.

# %%
import numpy as np
import xarray as xr
import gcsfs
import intake
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import xclim.ensembles as xce

# URLs for the Google Cloud CMIP6 ESM Collection Spec
url_google = "https://storage.googleapis.com/cmip6/pangeo-cmip6.json"

# %% [markdown]
# First let's take a look at the data catalog for the Google CMIP6 archive. This shows a summary of all the CMIP6 data available from this database.

# %%
catalog = intake.open_esm_datastore(url_google)
catalog
# Out:
# <p><strong>pangeo-cmip6 catalog with 7674 dataset(s) from 514818 asset(s)</strong>:</p> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>activity_id</th>
#       <td>18</td>
#     </tr>
#     <tr>
#       <th>institution_id</th>
#       <td>36</td>
#     </tr>
#     <tr>
#       <th>source_id</th>
#       <td>88</td>
#     </tr>
#     <tr>
#       <th>experiment_id</th>
#       <td>170</td>
#     </tr>
#     <tr>
#       <th>member_id</th>
#       <td>657</td>
#     </tr>
#     <tr>
#       <th>table_id</th>
#       <td>37</td>
#     </tr>
#     <tr>
#       <th>variable_id</th>
#       <td>700</td>
#     </tr>
#     <tr>
#       <th>grid_label</th>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>zstore</th>
#       <td>514818</td>
#     </tr>
#     <tr>
#       <th>dcpp_init_year</th>
#       <td>60</td>
#     </tr>
#     <tr>
#       <th>version</th>
#       <td>736</td>
#     </tr>
#     <tr>
#       <th>derived_variable_id</th>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Now let's search for a particular output variable from a certain model. The interface is similar to what we saw in Section 3.5, but we don't need to use a long string to query a dataframe. `intake-esm` has a function for that. To switch things up, let's now look for daily precipitation output for the historical and SSP3-7.0 simulations from the model IPSL-CM6A-LR.

# %%
search_result = catalog.search(source_id = "IPSL-CM6A-LR",
                               experiment_id=['historical', 'ssp370'], 
                               table_id='day', 
                               variable_id='pr')
# we can convert the search results to a pandas dataframe and print out the results
search_result.df
# Out:
#     activity_id institution_id     source_id experiment_id  member_id  \
# 0          CMIP           IPSL  IPSL-CM6A-LR    historical   r8i1p1f1
# 1          CMIP           IPSL  IPSL-CM6A-LR    historical   r2i1p1f1
# 2          CMIP           IPSL  IPSL-CM6A-LR    historical   r7i1p1f1
# 3          CMIP           IPSL  IPSL-CM6A-LR    historical  r31i1p1f1
# 4          CMIP           IPSL  IPSL-CM6A-LR    historical   r5i1p1f1
# 5          CMIP           IPSL  IPSL-CM6A-LR    historical  r26i1p1f1
# 6          CMIP           IPSL  IPSL-CM6A-LR    historical  r29i1p1f1
# 7          CMIP           IPSL  IPSL-CM6A-LR    historical   r6i1p1f1
# 8          CMIP           IPSL  IPSL-CM6A-LR    historical  r25i1p1f1
# 9          CMIP           IPSL  IPSL-CM6A-LR    historical  r20i1p1f1
# 10         CMIP           IPSL  IPSL-CM6A-LR    historical  r24i1p1f1
# 11         CMIP           IPSL  IPSL-CM6A-LR    historical  r28i1p1f1
# 12         CMIP           IPSL  IPSL-CM6A-LR    historical  r23i1p1f1
# 13         CMIP           IPSL  IPSL-CM6A-LR    historical  r21i1p1f1
# 14         CMIP           IPSL  IPSL-CM6A-LR    historical  r30i1p1f1
# 15         CMIP           IPSL  IPSL-CM6A-LR    historical  r22i1p1f1
# 16         CMIP           IPSL  IPSL-CM6A-LR    historical  r18i1p1f1
# 17         CMIP           IPSL  IPSL-CM6A-LR    historical  r17i1p1f1
# 18         CMIP           IPSL  IPSL-CM6A-LR    historical  r11i1p1f1
# 19         CMIP           IPSL  IPSL-CM6A-LR    historical  r15i1p1f1
# 20         CMIP           IPSL  IPSL-CM6A-LR    historical  r16i1p1f1
# 21         CMIP           IPSL  IPSL-CM6A-LR    historical  r19i1p1f1
# 22         CMIP           IPSL  IPSL-CM6A-LR    historical   r1i1p1f1
# 23         CMIP           IPSL  IPSL-CM6A-LR    historical   r4i1p1f1
# 24         CMIP           IPSL  IPSL-CM6A-LR    historical  r27i1p1f1
# 25         CMIP           IPSL  IPSL-CM6A-LR    historical   r3i1p1f1
# 26         CMIP           IPSL  IPSL-CM6A-LR    historical   r9i1p1f1
# 27         CMIP           IPSL  IPSL-CM6A-LR    historical  r14i1p1f1
# 28         CMIP           IPSL  IPSL-CM6A-LR    historical  r10i1p1f1
# 29         CMIP           IPSL  IPSL-CM6A-LR    historical  r13i1p1f1
# 30         CMIP           IPSL  IPSL-CM6A-LR    historical  r12i1p1f1
# 31  ScenarioMIP           IPSL  IPSL-CM6A-LR        ssp370   r2i1p1f1
# 32  ScenarioMIP           IPSL  IPSL-CM6A-LR        ssp370   r1i1p1f1
# 33  ScenarioMIP           IPSL  IPSL-CM6A-LR        ssp370  r10i1p1f1
# 34  ScenarioMIP           IPSL  IPSL-CM6A-LR        ssp370   r3i1p1f1
# 35  ScenarioMIP           IPSL  IPSL-CM6A-LR        ssp370   r4i1p1f1
# 36  ScenarioMIP           IPSL  IPSL-CM6A-LR        ssp370   r5i1p1f1
# 37  ScenarioMIP           IPSL  IPSL-CM6A-LR        ssp370   r6i1p1f1
# 38  ScenarioMIP           IPSL  IPSL-CM6A-LR        ssp370   r7i1p1f1
# 39  ScenarioMIP           IPSL  IPSL-CM6A-LR        ssp370   r9i1p1f1
# 40  ScenarioMIP           IPSL  IPSL-CM6A-LR        ssp370   r8i1p1f1
# 41         CMIP           IPSL  IPSL-CM6A-LR    historical  r32i1p1f1
# 42  ScenarioMIP           IPSL  IPSL-CM6A-LR        ssp370  r14i1p1f1
#
#    table_id variable_id grid_label  \
# 0       day          pr         gr
# 1       day          pr         gr
# 2       day          pr         gr
# 3       day          pr         gr
# 4       day          pr         gr
# 5       day          pr         gr
# 6       day          pr         gr
# 7       day          pr         gr
# 8       day          pr         gr
# 9       day          pr         gr
# 10      day          pr         gr
# 11      day          pr         gr
# 12      day          pr         gr
# 13      day          pr         gr
# 14      day          pr         gr
# 15      day          pr         gr
# 16      day          pr         gr
# 17      day          pr         gr
# 18      day          pr         gr
# 19      day          pr         gr
# 20      day          pr         gr
# 21      day          pr         gr
# 22      day          pr         gr
# 23      day          pr         gr
# 24      day          pr         gr
# 25      day          pr         gr
# 26      day          pr         gr
# 27      day          pr         gr
# 28      day          pr         gr
# 29      day          pr         gr
# 30      day          pr         gr
# 31      day          pr         gr
# 32      day          pr         gr
# 33      day          pr         gr
# 34      day          pr         gr
# 35      day          pr         gr
# 36      day          pr         gr
# 37      day          pr         gr
# 38      day          pr         gr
# 39      day          pr         gr
# 40      day          pr         gr
# 41      day          pr         gr
# 42      day          pr         gr
#
#                                                zstore  dcpp_init_year  \
# 0   gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/histor...             NaN
# 1   gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/histor...             NaN
# 2   gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/histor...             NaN
# 3   gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/histor...             NaN
# 4   gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/histor...             NaN
# 5   gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/histor...             NaN
# 6   gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/histor...             NaN
# 7   gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/histor...             NaN
# 8   gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/histor...             NaN
# 9   gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/histor...             NaN
# 10  gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/histor...             NaN
# 11  gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/histor...             NaN
# 12  gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/histor...             NaN
# 13  gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/histor...             NaN
# 14  gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/histor...             NaN
# 15  gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/histor...             NaN
# 16  gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/histor...             NaN
# 17  gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/histor...             NaN
# 18  gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/histor...             NaN
# 19  gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/histor...             NaN
# 20  gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/histor...             NaN
# 21  gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/histor...             NaN
# 22  gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/histor...             NaN
# 23  gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/histor...             NaN
# 24  gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/histor...             NaN
# 25  gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/histor...             NaN
# 26  gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/histor...             NaN
# 27  gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/histor...             NaN
# 28  gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/histor...             NaN
# 29  gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/histor...             NaN
# 30  gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/histor...             NaN
# 31  gs://cmip6/CMIP6/ScenarioMIP/IPSL/IPSL-CM6A-LR...             NaN
# 32  gs://cmip6/CMIP6/ScenarioMIP/IPSL/IPSL-CM6A-LR...             NaN
# 33  gs://cmip6/CMIP6/ScenarioMIP/IPSL/IPSL-CM6A-LR...             NaN
# 34  gs://cmip6/CMIP6/ScenarioMIP/IPSL/IPSL-CM6A-LR...             NaN
# 35  gs://cmip6/CMIP6/ScenarioMIP/IPSL/IPSL-CM6A-LR...             NaN
# 36  gs://cmip6/CMIP6/ScenarioMIP/IPSL/IPSL-CM6A-LR...             NaN
# 37  gs://cmip6/CMIP6/ScenarioMIP/IPSL/IPSL-CM6A-LR...             NaN
# 38  gs://cmip6/CMIP6/ScenarioMIP/IPSL/IPSL-CM6A-LR...             NaN
# 39  gs://cmip6/CMIP6/ScenarioMIP/IPSL/IPSL-CM6A-LR...             NaN
# 40  gs://cmip6/CMIP6/ScenarioMIP/IPSL/IPSL-CM6A-LR...             NaN
# 41  gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/histor...             NaN
# 42  gs://cmip6/CMIP6/ScenarioMIP/IPSL/IPSL-CM6A-LR...             NaN
#
#      version
# 0   20180803
# 1   20180803
# 2   20180803
# 3   20180803
# 4   20180803
# 5   20180803
# 6   20180803
# 7   20180803
# 8   20180803
# 9   20180803
# 10  20180803
# 11  20180803
# 12  20180803
# 13  20180803
# 14  20180803
# 15  20180803
# 16  20180803
# 17  20180803
# 18  20180803
# 19  20180803
# 20  20180803
# 21  20180803
# 22  20180803
# 23  20180803
# 24  20180803
# 25  20180803
# 26  20180803
# 27  20180803
# 28  20180803
# 29  20180803
# 30  20180803
# 31  20190119
# 32  20190119
# 33  20190119
# 34  20190119
# 35  20190119
# 36  20190119
# 37  20190119
# 38  20190119
# 39  20190119
# 40  20190119
# 41  20190802
# 42  20191122

# %% [markdown]
# In principle, `intake-esm` can load all of these datasets in one function call using `search_result.to_dataset_dict(zarr_kwargs={'consolidated': True})`. We'll do this, but to save time we'll reduce the size of the data request by  selecting only two ensemble members first.

# %%
# search again,specifying the ensemble members we want. Then print the dataframe again.
search_result_small = search_result.search(member_id = ['r1i1p1f1', 'r2i1p1f1'])
search_result_small.df
# Out:
#    activity_id institution_id     source_id experiment_id member_id table_id  \
# 0         CMIP           IPSL  IPSL-CM6A-LR    historical  r2i1p1f1      day
# 1         CMIP           IPSL  IPSL-CM6A-LR    historical  r1i1p1f1      day
# 2  ScenarioMIP           IPSL  IPSL-CM6A-LR        ssp370  r2i1p1f1      day
# 3  ScenarioMIP           IPSL  IPSL-CM6A-LR        ssp370  r1i1p1f1      day
#
#   variable_id grid_label                                             zstore  \
# 0          pr         gr  gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/histor...
# 1          pr         gr  gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/histor...
# 2          pr         gr  gs://cmip6/CMIP6/ScenarioMIP/IPSL/IPSL-CM6A-LR...
# 3          pr         gr  gs://cmip6/CMIP6/ScenarioMIP/IPSL/IPSL-CM6A-LR...
#
#    dcpp_init_year   version
# 0             NaN  20180803
# 1             NaN  20180803
# 2             NaN  20190119
# 3             NaN  20190119

# %%
# now load the data into a dictionary and print the keys
ds_dict = search_result_small.to_dataset_dict(zarr_kwargs={'consolidated': True})
list(ds_dict.keys())
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='2' class='' max='2' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2/2 00:07&lt;00:00]
#     </div>
# ['ScenarioMIP.IPSL.IPSL-CM6A-LR.ssp370.day.gr',
#  'CMIP.IPSL.IPSL-CM6A-LR.historical.day.gr']

# %% [markdown]
# `intake-esm` organized the datasets into a dictionary with two entries: one for the SSP3-7.0 scenario and one for the historical-forcing simulation. Did it put both realizations into a single dataset for each period? Let's see:

# %%
ds_dict['CMIP.IPSL.IPSL-CM6A-LR.historical.day.gr']
# Out:
# <xarray.Dataset> Size: 10GB
# Dimensions:         (member_id: 2, dcpp_init_year: 1, time: 60265, lat: 143,
#                      lon: 144, axis_nbounds: 2)
# Coordinates:
#   * lat             (lat) float32 572B -90.0 -88.73 -87.46 ... 87.46 88.73 90.0
#   * lon             (lon) float32 576B 0.0 2.5 5.0 7.5 ... 352.5 355.0 357.5
#   * time            (time) datetime64[ns] 482kB 1850-01-01T12:00:00 ... 2014-...
#     time_bounds     (time, axis_nbounds) datetime64[ns] 964kB dask.array<chunksize=(30133, 1), meta=np.ndarray>
#   * member_id       (member_id) object 16B 'r1i1p1f1' 'r2i1p1f1'
#   * dcpp_init_year  (dcpp_init_year) float64 8B nan
# Dimensions without coordinates: axis_nbounds
# Data variables:
#     pr              (member_id, dcpp_init_year, time, lat, lon) float32 10GB dask.array<chunksize=(1, 1, 843, 143, 144), meta=np.ndarray>
# Attributes: (12/53)
#     CMIP6_CV_version:                 cv=6.2.3.5-2-g63b123e
#     Conventions:                      CF-1.7 CMIP-6.2
#     EXPID:                            historical
#     NCO:                              "4.6.0"
#     activity_id:                      CMIP
#     branch_method:                    standard
#     ...                               ...
#     intake_esm_attrs:variable_id:     pr
#     intake_esm_attrs:grid_label:      gr
#     intake_esm_attrs:version:         20180803
#     intake_esm_attrs:_data_format_:   zarr
#     variant_info:                     Restart from another point in piControl...
#     intake_esm_dataset_key:           CMIP.IPSL.IPSL-CM6A-LR.historical.day.gr

# %% [markdown]
# Yes it did, awesome! The dimension `member_id` in the dataset represents the different ensemble members. You can see how using `intake-esm` to load data is extremely convenient.
#
# Some post-processing will be necessary to turn the data from a dictionary of different `xr.Dataset`s to a single `xr.Dataset`. For example, we may wish to concatenate the historical and SSP3-7.0 output into a single time series. This is fairly trivial, but we'll demonstrate how to do it anyway:

# %%
# extract each of the two datasets from the dictionary, and select an abritrary sample location
ds_historical = ds_dict['CMIP.IPSL.IPSL-CM6A-LR.historical.day.gr']
ds_ssp370 = ds_dict['ScenarioMIP.IPSL.IPSL-CM6A-LR.ssp370.day.gr']

# concatenate in time
ds_full_record = xr.concat([ds_historical, ds_ssp370], dim = 'time')
ds_full_record
# Out:
# <xarray.Dataset> Size: 15GB
# Dimensions:         (member_id: 2, dcpp_init_year: 1, time: 91676, lat: 143,
#                      lon: 144, axis_nbounds: 2)
# Coordinates:
#   * lat             (lat) float32 572B -90.0 -88.73 -87.46 ... 87.46 88.73 90.0
#   * lon             (lon) float32 576B 0.0 2.5 5.0 7.5 ... 352.5 355.0 357.5
#   * time            (time) datetime64[ns] 733kB 1850-01-01T12:00:00 ... 2100-...
#     time_bounds     (time, axis_nbounds) datetime64[ns] 1MB dask.array<chunksize=(30133, 1), meta=np.ndarray>
#   * member_id       (member_id) object 16B 'r1i1p1f1' 'r2i1p1f1'
#   * dcpp_init_year  (dcpp_init_year) float64 8B nan
# Dimensions without coordinates: axis_nbounds
# Data variables:
#     pr              (member_id, dcpp_init_year, time, lat, lon) float32 15GB dask.array<chunksize=(1, 1, 843, 143, 144), meta=np.ndarray>
# Attributes: (12/53)
#     CMIP6_CV_version:                 cv=6.2.3.5-2-g63b123e
#     Conventions:                      CF-1.7 CMIP-6.2
#     EXPID:                            historical
#     NCO:                              "4.6.0"
#     activity_id:                      CMIP
#     branch_method:                    standard
#     ...                               ...
#     intake_esm_attrs:variable_id:     pr
#     intake_esm_attrs:grid_label:      gr
#     intake_esm_attrs:version:         20180803
#     intake_esm_attrs:_data_format_:   zarr
#     variant_info:                     Restart from another point in piControl...
#     intake_esm_dataset_key:           CMIP.IPSL.IPSL-CM6A-LR.historical.day.gr

# %% [markdown]
# In order to handle data from multiple models, we can use `xclim.ensembles` to combine datasets for separate models into a single `xr.Dataset`.

# %%
# search for data from two models, one ensemble member.
search_result_multimodel = catalog.search(source_id = ["IPSL-CM6A-LR" ,'CESM2'],
                                          experiment_id='historical',
                                          member_id = 'r1i1p1f1',
                                          table_id='day', 
                                          variable_id='pr')
# print the results
search_result_multimodel.df
# Out:
#   activity_id institution_id     source_id experiment_id member_id table_id  \
# 0        CMIP           IPSL  IPSL-CM6A-LR    historical  r1i1p1f1      day
# 1        CMIP           NCAR         CESM2    historical  r1i1p1f1      day
#
#   variable_id grid_label                                             zstore  \
# 0          pr         gr  gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/histor...
# 1          pr         gn  gs://cmip6/CMIP6/CMIP/NCAR/CESM2/historical/r1...
#
#    dcpp_init_year   version
# 0             NaN  20180803
# 1             NaN  20190401

# %%
# access the data
ds_dict_multimodel = search_result_multimodel.to_dataset_dict(zarr_kwargs={'consolidated': True})
list(ds_dict_multimodel.keys())
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='2' class='' max='2' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2/2 00:00&lt;00:00]
#     </div>
# ['CMIP.IPSL.IPSL-CM6A-LR.historical.day.gr',
#  'CMIP.NCAR.CESM2.historical.day.gn']

# %%
# put both models into a single dataset
ds_multimodel = xce.create_ensemble([ds_dict_multimodel[k] for k in ds_dict_multimodel.keys()],                             
                                    realizations = ["IPSL-CM6A-LR" ,'CESM2'],
                                    calendar = 'noleap')
ds_multimodel
# Out:
# <xarray.Dataset> Size: 92GB
# Dimensions:         (realization: 2, member_id: 1, dcpp_init_year: 1,
#                      time: 120451, lat: 333, lon: 288, axis_nbounds: 2, nbnd: 2)
# Coordinates:
#   * lat             (lat) float64 3kB -90.0 -89.06 -88.73 ... 88.73 89.06 90.0
#   * lon             (lon) float64 2kB 0.0 1.25 2.5 3.75 ... 356.2 357.5 358.8
#   * time            (time) object 964kB 1850-01-01 00:00:00 ... 2015-01-01 00...
#   * member_id       (member_id) object 8B 'r1i1p1f1'
#   * dcpp_init_year  (dcpp_init_year) float64 8B nan
#     time_bounds     (time, axis_nbounds) datetime64[ns] 2MB dask.array<chunksize=(60227, 1), meta=np.ndarray>
#     lat_bnds        (lat, nbnd) float64 5kB dask.array<chunksize=(333, 2), meta=np.ndarray>
#     lon_bnds        (lon, nbnd) float64 5kB dask.array<chunksize=(288, 2), meta=np.ndarray>
#     time_bnds       (time, nbnd) object 2MB dask.array<chunksize=(60226, 1), meta=np.ndarray>
#   * realization     (realization) <U12 96B 'IPSL-CM6A-LR' 'CESM2'
# Dimensions without coordinates: axis_nbounds, nbnd
# Data variables:
#     pr              (realization, member_id, dcpp_init_year, time, lat, lon) float32 92GB dask.array<chunksize=(1, 1, 1, 1100, 333, 288), meta=np.ndarray>
# Attributes: (12/67)
#     CMIP6_CV_version:                 cv=6.2.3.5-2-g63b123e
#     Conventions:                      CF-1.7 CMIP-6.2
#     EXPID:                            historical
#     NCO:                              "4.6.0"
#     activity_id:                      CMIP
#     branch_method:                    standard
#     ...                               ...
#     intake_esm_attrs:variable_id:     pr
#     intake_esm_attrs:grid_label:      gr
#     intake_esm_attrs:zstore:          gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM6A-LR...
#     intake_esm_attrs:version:         20180803
#     intake_esm_attrs:_data_format_:   zarr
#     intake_esm_dataset_key:           CMIP.IPSL.IPSL-CM6A-LR.historical.day.gr
